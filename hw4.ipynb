# %% [markdown]
# Огляньте структуру датасету (Animals-10):
#
# ● визначте кількість класів (навчальна множина / тестова) - 10 класів
#
# ● виділіть тестову/валідаційну множину - 15%/15%
#
# ● структуру каталогів (папок) - 10 папок (у кожній власна тварина)
#
# ● ознайомтеся з форматом файлів - .jpeg

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

data_dir = r"C:\Users\іванна\Downloads\Animals-10\raw-img"
train_dir = r"C:\Users\іванна\Downloads\Animals-10\train"
validation_dir = r"C:\Users\іванна\Downloads\Animals-10\validation"
test_dir = r"C:\Users\іванна\Downloads\Animals-10\test"

for directory in [train_dir, validation_dir, test_dir]:
    if not os.path.exists(directory):
        os.makedirs(directory)

for class_name in os.listdir(data_dir):
    class_path = os.path.join(data_dir, class_name)

    if os.path.isdir(class_path):
        files = os.listdir(class_path)

        # навчальна (70%), валідаційна (15%) та тестова (15%) множини
        train_files, temp_files = train_test_split(files, test_size=0.3, random_state=42)  # 70% train, 30% for val + test
        val_files, test_files = train_test_split(temp_files, test_size=0.5, random_state=42)  # 50% of the 30% for validation, 50% for test

        train_class_dir = os.path.join(train_dir, class_name)
        val_class_dir = os.path.join(validation_dir, class_name)
        test_class_dir = os.path.join(test_dir, class_name)

        for directory in [train_class_dir, val_class_dir, test_class_dir]:
            if not os.path.exists(directory):
                os.makedirs(directory)

        for file in train_files:
            shutil.move(os.path.join(class_path, file), os.path.join(train_class_dir, file))

        for file in val_files:
            shutil.move(os.path.join(class_path, file), os.path.join(val_class_dir, file))

        for file in test_files:
            shutil.move(os.path.join(class_path, file), os.path.join(test_class_dir, file))

# %%
import os
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

train_dir = r"C:\Users\іванна\Downloads\Animals-10\train"
val_dir = r"C:\Users\іванна\Downloads\Animals-10\validation"
test_dir = r"C:\Users\іванна\Downloads\Animals-10\test"

transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
])

train_dataset = datasets.ImageFolder(root=train_dir, transform=transform)
val_dataset = datasets.ImageFolder(root=val_dir, transform=transform)
test_dataset = datasets.ImageFolder(root=test_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

for images, labels in train_loader:
    print(images.shape)
    break
# Out:
# torch.Size([64, 3, 128, 128])

# %% [markdown]
# З аугментацією:

# %%
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(30),
    transforms.RandomResizedCrop(128, scale=(0.8, 1.0)),
    transforms.ToTensor(),
])

val_transform = transforms.Compose([
    transforms.Resize(128),
    transforms.CenterCrop(128),
    transforms.ToTensor(),
])

train_dataset = datasets.ImageFolder(root=train_dir, transform=train_transform)
val_dataset = datasets.ImageFolder(root=validation_dir, transform=val_transform)
test_dataset = datasets.ImageFolder(root=test_dir, transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
import numpy as np
import matplotlib.pyplot as plt
def show_images_from_classes(data_loader, num_images=5):
    data_iter = iter(data_loader)
    images, labels = next(data_iter)
    train_dir = "/content/drive/MyDrive/train"
    class_names = os.listdir(train_dir)
    class_names1 = ['cane (dog)',  'cavallo (horse)', 'elefante (elephant)', 'farfalla (butterfly)',  'gallina (chicken)', 'gatto (cat)', 'mucca (cow)', 'pecora (sheep)', 'ragno (spider)', 'scoiattolo (squirrel)']
    print(class_names)
    fig, axes = plt.subplots(1, num_images, figsize=(15, 5))

    for i in range(num_images):
        ax = axes[i]
        image = images[i].numpy().transpose((1, 2, 0))
        image = np.clip(image, 0, 1)
        ax.imshow(image)
        ax.set_title(f"{class_names1[labels[i].item()]}")
       # ax.set_title(f"Class: {labels[i].item()}")
        ax.axis('off')

    plt.show()

show_images_from_classes(train_loader, num_images=5)
# Out:
# ['elefante', 'farfalla', 'mucca', 'gallina', 'gatto', 'cavallo', 'pecora', 'scoiattolo', 'cane', 'ragno']

# %%
import os
import matplotlib.pyplot as plt

train_dir = "/content/drive/MyDrive/train"
class_names = os.listdir(train_dir)
class_names1 = ['cane (dog)',  'cavallo (horse)', 'elefante (elephant)', 'farfalla (butterfly)',  'gallina (chicken)', 'gatto (cat)', 'mucca (cow)', 'pecora (sheep)', 'ragno (spider)', 'scoiattolo (squirrel)']

image_counts = []

for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):
        image_counts.append(len(os.listdir(class_path)))

plt.figure(figsize=(12, 6))
plt.bar(class_names, image_counts, color='skyblue')
plt.xlabel('Classes')
plt.ylabel('Number of images')
plt.title('Number of images per class')
plt.tight_layout()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from sklearn.metrics import accuracy_score, f1_score
import matplotlib.pyplot as plt

class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=5, padding=2)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=5, padding=2)
        self.conv3 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1)

        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        self.bn1 = nn.BatchNorm2d(64)
        self.bn2 = nn.BatchNorm2d(128)
        self.bn3 = nn.BatchNorm2d(256)

        self.fc1 = nn.Linear(256 * 16 * 16, 1024)
        self.fc2 = nn.Linear(1024, 10)

        self.relu = nn.ReLU()
        self.softmax = nn.Softmax(dim=1)

        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        x = self.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)

        x = self.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)

        x = self.relu(self.bn3(self.conv3(x)))
        x = self.pool(x)

        x = x.view(-1, 256 * 16 * 16)

        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)

        return self.softmax(x)

# %%
def initialize_model():
    model = SimpleCNN()
    model.to(device)
    class_counts = torch.tensor([800, 1200, 1000, 1700, 1000, 1500, 1000, 1000, 2700, 2700])
    total_images = class_counts.sum()
    class_weights = total_images / class_counts
    class_weights_tensor = class_weights.float().to(device)
    #class_weights = 1. / class_counts
    #weights = class_weights[labels]
    #criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.0001)
    return model, criterion, optimizer

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
])

train_dir = r"C:\Users\іванна\Downloads\Animals-10\train"
val_dir = r"C:\Users\іванна\Downloads\Animals-10\validation"
test_dir = r"C:\Users\іванна\Downloads\Animals-10\test"

train_dataset = datasets.ImageFolder(root=train_dir, transform=transform)
val_dataset = datasets.ImageFolder(root=val_dir, transform=transform)
test_dataset = datasets.ImageFolder(root=test_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
model, criterion, optimizer = initialize_model()

# %%
print(torch.cuda.is_available())
# Out:
# False

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model.to(device)
# Out:
# Using device: cpu
# SimpleCNN(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=65536, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=10, bias=True)
#   (relu): ReLU()
#   (softmax): Softmax(dim=1)
# )

# %%
import math
num_images = len(train_loader.dataset)
batch_size = 64
num_batches = math.ceil(num_images / batch_size)
print(f"Кількість батчів: {num_batches}")
# Out:
# Кількість батчів: 287

# %%
import time

num_epochs = 2
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
train_f1_scores = []
val_f1_scores = []

for epoch in range(num_epochs):
    start_time = time.time()
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    all_labels_train = []
    all_preds_train = []

    for batch_idx, (inputs, labels) in enumerate(train_loader):
        optimizer.zero_grad()
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)

        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()
        all_labels_train.extend(labels.cpu().numpy())
        all_preds_train.extend(predicted.cpu().numpy())

        batch_accuracy = (predicted == labels).sum().item() / labels.size(0)
        batch_f1 = f1_score(labels.cpu().numpy(), predicted.cpu().numpy(), average='weighted')
        print(f"Epoch {epoch+1}/{num_epochs}, Batch {batch_idx}, Loss: {loss.item():.4f}, Accuracy: {batch_accuracy:.4f}, F1 Score: {batch_f1:.4f}")

    train_accuracy = correct_train / total_train
    train_f1 = f1_score(all_labels_train, all_preds_train, average='weighted')

    # Валідація
    model.eval()
    correct_val = 0
    total_val = 0
    all_labels_val = []
    all_preds_val = []
    val_loss = 0.0

    with torch.no_grad():
        for inputs, labels in val_loader:
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()
            all_labels_val.extend(labels.cpu().numpy())
            all_preds_val.extend(predicted.cpu().numpy())

    val_accuracy = correct_val / total_val
    val_f1 = f1_score(all_labels_val, all_preds_val, average='weighted')

    train_losses.append(running_loss / len(train_loader))
    val_losses.append(val_loss / len(val_loader))
    train_accuracies.append(train_accuracy)
    val_accuracies.append(val_accuracy)
    train_f1_scores.append(train_f1)
    val_f1_scores.append(val_f1)

    epoch_time = time.time() - start_time
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_losses[-1]:.4f}, Train Accuracy: {train_accuracies[-1]:.4f}, Train F1: {train_f1_scores[-1]:.4f}")
    print(f"Epoch {epoch+1}/{num_epochs}, Val Loss: {val_losses[-1]:.4f}, Val Accuracy: {val_accuracies[-1]:.4f}, Val F1: {val_f1_scores[-1]:.4f}")
    print(f"Time for Epoch {epoch+1}: {epoch_time:.2f} seconds")
# Out:
# Epoch 1/2, Batch 0, Loss: 2.3103, Accuracy: 0.0938, F1 Score: 0.0751
# Epoch 1/2, Batch 1, Loss: 2.2826, Accuracy: 0.1719, F1 Score: 0.0904
# Epoch 1/2, Batch 2, Loss: 2.2296, Accuracy: 0.2188, F1 Score: 0.1019
# Epoch 1/2, Batch 3, Loss: 2.3036, Accuracy: 0.1562, F1 Score: 0.0428
# Epoch 1/2, Batch 4, Loss: 2.2379, Accuracy: 0.2031, F1 Score: 0.0954
# Epoch 1/2, Batch 5, Loss: 2.3005, Accuracy: 0.1719, F1 Score: 0.0975
# Epoch 1/2, Batch 6, Loss: 2.2210, Accuracy: 0.2344, F1 Score: 0.1369
# Epoch 1/2, Batch 7, Loss: 2.2529, Accuracy: 0.2031, F1 Score: 0.1119
# Epoch 1/2, Batch 8, Loss: 2.2767, Accuracy: 0.1875, F1 Score: 0.1331
# Epoch 1/2, Batch 9, Loss: 2.2521, Accuracy: 0.2031, F1 Score: 0.0916
# Epoch 1/2, Batch 10, Loss: 2.2806, Accuracy: 0.1719, F1 Score: 0.0672
# Epoch 1/2, Batch 11, Loss: 2.2944, Accuracy: 0.1719, F1 Score: 0.0833
# Epoch 1/2, Batch 12, Loss: 2.2608, Accuracy: 0.1875, F1 Score: 0.0913
# Epoch 1/2, Batch 13, Loss: 2.2718, Accuracy: 0.1875, F1 Score: 0.0968
# Epoch 1/2, Batch 14, Loss: 2.1639, Accuracy: 0.2969, F1 Score: 0.1961
# Epoch 1/2, Batch 15, Loss: 2.3022, Accuracy: 0.1562, F1 Score: 0.0807
# Epoch 1/2, Batch 16, Loss: 2.2500, Accuracy: 0.2031, F1 Score: 0.0947
# Epoch 1/2, Batch 17, Loss: 2.1881, Accuracy: 0.2812, F1 Score: 0.1619
# Epoch 1/2, Batch 18, Loss: 2.1959, Accuracy: 0.2656, F1 Score: 0.1489
# Epoch 1/2, Batch 19, Loss: 2.3212, Accuracy: 0.1406, F1 Score: 0.0801
# Epoch 1/2, Batch 20, Loss: 2.2892, Accuracy: 0.1719, F1 Score: 0.0815
# Epoch 1/2, Batch 21, Loss: 2.3633, Accuracy: 0.0938, F1 Score: 0.0193
# Epoch 1/2, Batch 22, Loss: 2.3257, Accuracy: 0.1250, F1 Score: 0.0458
# Epoch 1/2, Batch 23, Loss: 2.2716, Accuracy: 0.1875, F1 Score: 0.0915
# Epoch 1/2, Batch 24, Loss: 2.1936, Accuracy: 0.2656, F1 Score: 0.1460
# Epoch 1/2, Batch 25, Loss: 2.1871, Accuracy: 0.2812, F1 Score: 0.1447
# Epoch 1/2, Batch 26, Loss: 2.1990, Accuracy: 0.2656, F1 Score: 0.1514
# Epoch 1/2, Batch 27, Loss: 2.2411, Accuracy: 0.2188, F1 Score: 0.1000
# Epoch 1/2, Batch 28, Loss: 2.3019, Accuracy: 0.1562, F1 Score: 0.0718
# Epoch 1/2, Batch 29, Loss: 2.2486, Accuracy: 0.2188, F1 Score: 0.1175
# Epoch 1/2, Batch 30, Loss: 2.2409, Accuracy: 0.2188, F1 Score: 0.1464
# Epoch 1/2, Batch 31, Loss: 2.2724, Accuracy: 0.1875, F1 Score: 0.1015
# Epoch 1/2, Batch 32, Loss: 2.2229, Accuracy: 0.2344, F1 Score: 0.1152
# Epoch 1/2, Batch 33, Loss: 2.2084, Accuracy: 0.2500, F1 Score: 0.1451
# Epoch 1/2, Batch 34, Loss: 2.1793, Accuracy: 0.2812, F1 Score: 0.1444
# Epoch 1/2, Batch 35, Loss: 2.2250, Accuracy: 0.2344, F1 Score: 0.1207
# Epoch 1/2, Batch 36, Loss: 2.2579, Accuracy: 0.2031, F1 Score: 0.1188
# Epoch 1/2, Batch 37, Loss: 2.2560, Accuracy: 0.2031, F1 Score: 0.1018
# Epoch 1/2, Batch 38, Loss: 2.2177, Accuracy: 0.2344, F1 Score: 0.1350
# Epoch 1/2, Batch 39, Loss: 2.2419, Accuracy: 0.2188, F1 Score: 0.1256
# Epoch 1/2, Batch 40, Loss: 2.2532, Accuracy: 0.2188, F1 Score: 0.0991
# Epoch 1/2, Batch 41, Loss: 2.3037, Accuracy: 0.1562, F1 Score: 0.0827
# Epoch 1/2, Batch 42, Loss: 2.2761, Accuracy: 0.1875, F1 Score: 0.0871
# Epoch 1/2, Batch 43, Loss: 2.2474, Accuracy: 0.2188, F1 Score: 0.1356
# Epoch 1/2, Batch 44, Loss: 2.3284, Accuracy: 0.1406, F1 Score: 0.0709
# Epoch 1/2, Batch 45, Loss: 2.2771, Accuracy: 0.1875, F1 Score: 0.0938
# Epoch 1/2, Batch 46, Loss: 2.2908, Accuracy: 0.1562, F1 Score: 0.0895
# Epoch 1/2, Batch 47, Loss: 2.2526, Accuracy: 0.2031, F1 Score: 0.0927
# Epoch 1/2, Batch 48, Loss: 2.2306, Accuracy: 0.2344, F1 Score: 0.1286
# Epoch 1/2, Batch 49, Loss: 2.3046, Accuracy: 0.1562, F1 Score: 0.0785
# Epoch 1/2, Batch 50, Loss: 2.2410, Accuracy: 0.2188, F1 Score: 0.1243
# Epoch 1/2, Batch 51, Loss: 2.2418, Accuracy: 0.2188, F1 Score: 0.1075
# Epoch 1/2, Batch 52, Loss: 2.2500, Accuracy: 0.2031, F1 Score: 0.1047
# Epoch 1/2, Batch 53, Loss: 2.1990, Accuracy: 0.2656, F1 Score: 0.1575
# Epoch 1/2, Batch 54, Loss: 2.1565, Accuracy: 0.3125, F1 Score: 0.1927
# Epoch 1/2, Batch 55, Loss: 2.2572, Accuracy: 0.2031, F1 Score: 0.1081
# Epoch 1/2, Batch 56, Loss: 2.1935, Accuracy: 0.2656, F1 Score: 0.1445
# Epoch 1/2, Batch 57, Loss: 2.2764, Accuracy: 0.1875, F1 Score: 0.1094
# Epoch 1/2, Batch 58, Loss: 2.1754, Accuracy: 0.2812, F1 Score: 0.1696
# Epoch 1/2, Batch 59, Loss: 2.2348, Accuracy: 0.2188, F1 Score: 0.1441
# Epoch 1/2, Batch 60, Loss: 2.2124, Accuracy: 0.2500, F1 Score: 0.1219
# Epoch 1/2, Batch 61, Loss: 2.1575, Accuracy: 0.3125, F1 Score: 0.1791
# Epoch 1/2, Batch 62, Loss: 2.1618, Accuracy: 0.3125, F1 Score: 0.2042
# Epoch 1/2, Batch 63, Loss: 2.2021, Accuracy: 0.2500, F1 Score: 0.1271
# Epoch 1/2, Batch 64, Loss: 2.2261, Accuracy: 0.2344, F1 Score: 0.1155
# Epoch 1/2, Batch 65, Loss: 2.2079, Accuracy: 0.2656, F1 Score: 0.1475
# Epoch 1/2, Batch 66, Loss: 2.2723, Accuracy: 0.1875, F1 Score: 0.0825
# Epoch 1/2, Batch 67, Loss: 2.2261, Accuracy: 0.2344, F1 Score: 0.1173
# Epoch 1/2, Batch 68, Loss: 2.1645, Accuracy: 0.2969, F1 Score: 0.1769
# Epoch 1/2, Batch 69, Loss: 2.2411, Accuracy: 0.2188, F1 Score: 0.0911
# Epoch 1/2, Batch 70, Loss: 2.1799, Accuracy: 0.2812, F1 Score: 0.1622
# Epoch 1/2, Batch 71, Loss: 2.2480, Accuracy: 0.2031, F1 Score: 0.0905
# Epoch 1/2, Batch 72, Loss: 2.2256, Accuracy: 0.2344, F1 Score: 0.0995
# Epoch 1/2, Batch 73, Loss: 2.1385, Accuracy: 0.3125, F1 Score: 0.1846
# Epoch 1/2, Batch 74, Loss: 2.1471, Accuracy: 0.3125, F1 Score: 0.1800
# Epoch 1/2, Batch 75, Loss: 2.2523, Accuracy: 0.2031, F1 Score: 0.0841
# Epoch 1/2, Batch 76, Loss: 2.2288, Accuracy: 0.2344, F1 Score: 0.1273
# Epoch 1/2, Batch 77, Loss: 2.1325, Accuracy: 0.3281, F1 Score: 0.1897
# Epoch 1/2, Batch 78, Loss: 2.1321, Accuracy: 0.3281, F1 Score: 0.2029
# Epoch 1/2, Batch 79, Loss: 2.1845, Accuracy: 0.2812, F1 Score: 0.1603
# Epoch 1/2, Batch 80, Loss: 2.2091, Accuracy: 0.2500, F1 Score: 0.1267
# Epoch 1/2, Batch 81, Loss: 2.1609, Accuracy: 0.2969, F1 Score: 0.1662
# Epoch 1/2, Batch 82, Loss: 2.1854, Accuracy: 0.2812, F1 Score: 0.1971
# Epoch 1/2, Batch 83, Loss: 2.2635, Accuracy: 0.1875, F1 Score: 0.0945
# Epoch 1/2, Batch 84, Loss: 2.1740, Accuracy: 0.2812, F1 Score: 0.1757
# Epoch 1/2, Batch 85, Loss: 2.2850, Accuracy: 0.1719, F1 Score: 0.0873
# Epoch 1/2, Batch 86, Loss: 2.2073, Accuracy: 0.2500, F1 Score: 0.1492
# Epoch 1/2, Batch 87, Loss: 2.2556, Accuracy: 0.2031, F1 Score: 0.0982
# Epoch 1/2, Batch 88, Loss: 2.2086, Accuracy: 0.2344, F1 Score: 0.1277
# Epoch 1/2, Batch 89, Loss: 2.1512, Accuracy: 0.3125, F1 Score: 0.1760
# Epoch 1/2, Batch 90, Loss: 2.1985, Accuracy: 0.2656, F1 Score: 0.1242
# Epoch 1/2, Batch 91, Loss: 2.2622, Accuracy: 0.2031, F1 Score: 0.0894
# Epoch 1/2, Batch 92, Loss: 2.2243, Accuracy: 0.2344, F1 Score: 0.1319
# Epoch 1/2, Batch 93, Loss: 2.2324, Accuracy: 0.2188, F1 Score: 0.1118
# Epoch 1/2, Batch 94, Loss: 2.1624, Accuracy: 0.2969, F1 Score: 0.1801
# Epoch 1/2, Batch 95, Loss: 2.1507, Accuracy: 0.3125, F1 Score: 0.2029
# Epoch 1/2, Batch 96, Loss: 2.3148, Accuracy: 0.1406, F1 Score: 0.0862
# Epoch 1/2, Batch 97, Loss: 2.1970, Accuracy: 0.2656, F1 Score: 0.1417
# Epoch 1/2, Batch 98, Loss: 2.1779, Accuracy: 0.2812, F1 Score: 0.1466
# Epoch 1/2, Batch 99, Loss: 2.2002, Accuracy: 0.2656, F1 Score: 0.1659
# Epoch 1/2, Batch 100, Loss: 2.1465, Accuracy: 0.3125, F1 Score: 0.1944
# Epoch 1/2, Batch 101, Loss: 2.1955, Accuracy: 0.2656, F1 Score: 0.1617
# Epoch 1/2, Batch 102, Loss: 2.1945, Accuracy: 0.2656, F1 Score: 0.1261
# Epoch 1/2, Batch 103, Loss: 2.2504, Accuracy: 0.2031, F1 Score: 0.1043
# Epoch 1/2, Batch 104, Loss: 2.1648, Accuracy: 0.2969, F1 Score: 0.1666
# Epoch 1/2, Batch 105, Loss: 2.2201, Accuracy: 0.2344, F1 Score: 0.1345
# Epoch 1/2, Batch 106, Loss: 2.2018, Accuracy: 0.2656, F1 Score: 0.1458
# Epoch 1/2, Batch 107, Loss: 2.2439, Accuracy: 0.2188, F1 Score: 0.1234
# Epoch 1/2, Batch 108, Loss: 2.2277, Accuracy: 0.2344, F1 Score: 0.1344
# Epoch 1/2, Batch 109, Loss: 2.2228, Accuracy: 0.2188, F1 Score: 0.1048
# Epoch 1/2, Batch 110, Loss: 2.2423, Accuracy: 0.2188, F1 Score: 0.1079
# Epoch 1/2, Batch 111, Loss: 2.2434, Accuracy: 0.2188, F1 Score: 0.0871
# Epoch 1/2, Batch 112, Loss: 2.0815, Accuracy: 0.3594, F1 Score: 0.2432
# Epoch 1/2, Batch 113, Loss: 2.1213, Accuracy: 0.3438, F1 Score: 0.2401
# Epoch 1/2, Batch 114, Loss: 2.1806, Accuracy: 0.2812, F1 Score: 0.1595
# Epoch 1/2, Batch 115, Loss: 2.1556, Accuracy: 0.3125, F1 Score: 0.1754
# Epoch 1/2, Batch 116, Loss: 2.1333, Accuracy: 0.3281, F1 Score: 0.2174
# Epoch 1/2, Batch 117, Loss: 2.1947, Accuracy: 0.2656, F1 Score: 0.1543
# Epoch 1/2, Batch 118, Loss: 2.1636, Accuracy: 0.2969, F1 Score: 0.2045
# Epoch 1/2, Batch 119, Loss: 2.1675, Accuracy: 0.2969, F1 Score: 0.1784
# Epoch 1/2, Batch 120, Loss: 2.1242, Accuracy: 0.3438, F1 Score: 0.2368
# Epoch 1/2, Batch 121, Loss: 2.2090, Accuracy: 0.2500, F1 Score: 0.1272
# Epoch 1/2, Batch 122, Loss: 2.2934, Accuracy: 0.1719, F1 Score: 0.0869
# Epoch 1/2, Batch 123, Loss: 2.1168, Accuracy: 0.3438, F1 Score: 0.2510
# Epoch 1/2, Batch 124, Loss: 2.3271, Accuracy: 0.1406, F1 Score: 0.0542
# Epoch 1/2, Batch 125, Loss: 2.1783, Accuracy: 0.2812, F1 Score: 0.1376
# Epoch 1/2, Batch 126, Loss: 2.1608, Accuracy: 0.2969, F1 Score: 0.1762
# Epoch 1/2, Batch 127, Loss: 2.3169, Accuracy: 0.1406, F1 Score: 0.0800
# Epoch 1/2, Batch 128, Loss: 2.1819, Accuracy: 0.2812, F1 Score: 0.1639
# Epoch 1/2, Batch 129, Loss: 2.2631, Accuracy: 0.2031, F1 Score: 0.1171
# Epoch 1/2, Batch 130, Loss: 2.2866, Accuracy: 0.1719, F1 Score: 0.0740
# Epoch 1/2, Batch 131, Loss: 2.0862, Accuracy: 0.3750, F1 Score: 0.2409
# Epoch 1/2, Batch 132, Loss: 2.1825, Accuracy: 0.2812, F1 Score: 0.1628
# Epoch 1/2, Batch 133, Loss: 2.1438, Accuracy: 0.3125, F1 Score: 0.1761
# Epoch 1/2, Batch 134, Loss: 2.2288, Accuracy: 0.2344, F1 Score: 0.1111
# Epoch 1/2, Batch 135, Loss: 2.1750, Accuracy: 0.2812, F1 Score: 0.1474
# Epoch 1/2, Batch 136, Loss: 2.2291, Accuracy: 0.2344, F1 Score: 0.1338
# Epoch 1/2, Batch 137, Loss: 2.2090, Accuracy: 0.2500, F1 Score: 0.1271
# Epoch 1/2, Batch 138, Loss: 2.1741, Accuracy: 0.2812, F1 Score: 0.1797
# Epoch 1/2, Batch 139, Loss: 2.1892, Accuracy: 0.2656, F1 Score: 0.1433
# Epoch 1/2, Batch 140, Loss: 2.2093, Accuracy: 0.2500, F1 Score: 0.1294
# Epoch 1/2, Batch 141, Loss: 2.2202, Accuracy: 0.2344, F1 Score: 0.1320
# Epoch 1/2, Batch 142, Loss: 2.2349, Accuracy: 0.2344, F1 Score: 0.1221
# Epoch 1/2, Batch 143, Loss: 2.2218, Accuracy: 0.2344, F1 Score: 0.1245
# Epoch 1/2, Batch 144, Loss: 2.1938, Accuracy: 0.2656, F1 Score: 0.1392
# Epoch 1/2, Batch 145, Loss: 2.2456, Accuracy: 0.2188, F1 Score: 0.1203
# Epoch 1/2, Batch 146, Loss: 2.1629, Accuracy: 0.2969, F1 Score: 0.1838
# Epoch 1/2, Batch 147, Loss: 2.2349, Accuracy: 0.2188, F1 Score: 0.1088
# Epoch 1/2, Batch 148, Loss: 2.1501, Accuracy: 0.3125, F1 Score: 0.1770
# Epoch 1/2, Batch 149, Loss: 2.1702, Accuracy: 0.2969, F1 Score: 0.1682
# Epoch 1/2, Batch 150, Loss: 2.1049, Accuracy: 0.3750, F1 Score: 0.2578
# Epoch 1/2, Batch 151, Loss: 2.1623, Accuracy: 0.2969, F1 Score: 0.1794
# Epoch 1/2, Batch 152, Loss: 2.2079, Accuracy: 0.2500, F1 Score: 0.1339
# Epoch 1/2, Batch 153, Loss: 2.1721, Accuracy: 0.2812, F1 Score: 0.1767
# Epoch 1/2, Batch 154, Loss: 2.2406, Accuracy: 0.2188, F1 Score: 0.1139
# Epoch 1/2, Batch 155, Loss: 2.1798, Accuracy: 0.2812, F1 Score: 0.1734
# Epoch 1/2, Batch 156, Loss: 2.1044, Accuracy: 0.3594, F1 Score: 0.2240
# Epoch 1/2, Batch 157, Loss: 2.2457, Accuracy: 0.2188, F1 Score: 0.1281
# Epoch 1/2, Batch 158, Loss: 2.1221, Accuracy: 0.3438, F1 Score: 0.2083
# Epoch 1/2, Batch 159, Loss: 2.2308, Accuracy: 0.2344, F1 Score: 0.1164
# Epoch 1/2, Batch 160, Loss: 2.1933, Accuracy: 0.2656, F1 Score: 0.1545
# Epoch 1/2, Batch 161, Loss: 2.1856, Accuracy: 0.2812, F1 Score: 0.1718
# Epoch 1/2, Batch 162, Loss: 2.1965, Accuracy: 0.2656, F1 Score: 0.1490
# Epoch 1/2, Batch 163, Loss: 2.1914, Accuracy: 0.2656, F1 Score: 0.1536
# Epoch 1/2, Batch 164, Loss: 2.2214, Accuracy: 0.2344, F1 Score: 0.1363
# Epoch 1/2, Batch 165, Loss: 2.1023, Accuracy: 0.3594, F1 Score: 0.2287
# Epoch 1/2, Batch 166, Loss: 2.1788, Accuracy: 0.2812, F1 Score: 0.1440
# Epoch 1/2, Batch 167, Loss: 2.2315, Accuracy: 0.2188, F1 Score: 0.1153
# Epoch 1/2, Batch 168, Loss: 2.2409, Accuracy: 0.2188, F1 Score: 0.1022
# Epoch 1/2, Batch 169, Loss: 2.1987, Accuracy: 0.2500, F1 Score: 0.1541
# Epoch 1/2, Batch 170, Loss: 2.1168, Accuracy: 0.3438, F1 Score: 0.2035
# Epoch 1/2, Batch 171, Loss: 2.1360, Accuracy: 0.3281, F1 Score: 0.1948
# Epoch 1/2, Batch 172, Loss: 2.1116, Accuracy: 0.3281, F1 Score: 0.2085
# Epoch 1/2, Batch 173, Loss: 2.2739, Accuracy: 0.1875, F1 Score: 0.0868
# Epoch 1/2, Batch 174, Loss: 2.1591, Accuracy: 0.3125, F1 Score: 0.1808
# Epoch 1/2, Batch 175, Loss: 2.2386, Accuracy: 0.2188, F1 Score: 0.0959
# Epoch 1/2, Batch 176, Loss: 2.2425, Accuracy: 0.2188, F1 Score: 0.1159
# Epoch 1/2, Batch 177, Loss: 2.2894, Accuracy: 0.1719, F1 Score: 0.0842
# Epoch 1/2, Batch 178, Loss: 2.2100, Accuracy: 0.2500, F1 Score: 0.1244
# Epoch 1/2, Batch 179, Loss: 2.1976, Accuracy: 0.2656, F1 Score: 0.1313
# Epoch 1/2, Batch 180, Loss: 2.2187, Accuracy: 0.2344, F1 Score: 0.1295
# Epoch 1/2, Batch 181, Loss: 2.1388, Accuracy: 0.3281, F1 Score: 0.1768
# Epoch 1/2, Batch 182, Loss: 2.1753, Accuracy: 0.2812, F1 Score: 0.1712
# Epoch 1/2, Batch 183, Loss: 2.1484, Accuracy: 0.3125, F1 Score: 0.1703
# Epoch 1/2, Batch 184, Loss: 2.2184, Accuracy: 0.2344, F1 Score: 0.1457
# Epoch 1/2, Batch 185, Loss: 2.2617, Accuracy: 0.1875, F1 Score: 0.0867
# Epoch 1/2, Batch 186, Loss: 2.2264, Accuracy: 0.2344, F1 Score: 0.1074
# Epoch 1/2, Batch 187, Loss: 2.1734, Accuracy: 0.2812, F1 Score: 0.1382
# Epoch 1/2, Batch 188, Loss: 2.2398, Accuracy: 0.2188, F1 Score: 0.1191
# Epoch 1/2, Batch 189, Loss: 2.2419, Accuracy: 0.2188, F1 Score: 0.1252
# Epoch 1/2, Batch 190, Loss: 2.1960, Accuracy: 0.2656, F1 Score: 0.1346
# Epoch 1/2, Batch 191, Loss: 2.2297, Accuracy: 0.2188, F1 Score: 0.1003
# Epoch 1/2, Batch 192, Loss: 2.1615, Accuracy: 0.2969, F1 Score: 0.1659
# Epoch 1/2, Batch 193, Loss: 2.2552, Accuracy: 0.2031, F1 Score: 0.0858
# Epoch 1/2, Batch 194, Loss: 2.2973, Accuracy: 0.1562, F1 Score: 0.0652
# Epoch 1/2, Batch 195, Loss: 2.1791, Accuracy: 0.2812, F1 Score: 0.1541
# Epoch 1/2, Batch 196, Loss: 2.0774, Accuracy: 0.3750, F1 Score: 0.2589
# Epoch 1/2, Batch 197, Loss: 2.2761, Accuracy: 0.1875, F1 Score: 0.0807
# Epoch 1/2, Batch 198, Loss: 2.2023, Accuracy: 0.2500, F1 Score: 0.1280
# Epoch 1/2, Batch 199, Loss: 2.2093, Accuracy: 0.2500, F1 Score: 0.1280
# Epoch 1/2, Batch 200, Loss: 2.2630, Accuracy: 0.2031, F1 Score: 0.0901
# Epoch 1/2, Batch 201, Loss: 2.1943, Accuracy: 0.2656, F1 Score: 0.1584
# Epoch 1/2, Batch 202, Loss: 2.1802, Accuracy: 0.2812, F1 Score: 0.1510
# Epoch 1/2, Batch 203, Loss: 2.2876, Accuracy: 0.1719, F1 Score: 0.0710
# Epoch 1/2, Batch 204, Loss: 2.2120, Accuracy: 0.2500, F1 Score: 0.1325
# Epoch 1/2, Batch 205, Loss: 2.1832, Accuracy: 0.2812, F1 Score: 0.1477
# Epoch 1/2, Batch 206, Loss: 2.2423, Accuracy: 0.2188, F1 Score: 0.1097
# Epoch 1/2, Batch 207, Loss: 2.1339, Accuracy: 0.3281, F1 Score: 0.2135
# Epoch 1/2, Batch 208, Loss: 2.0553, Accuracy: 0.4062, F1 Score: 0.2412
# Epoch 1/2, Batch 209, Loss: 2.2210, Accuracy: 0.2500, F1 Score: 0.1326
# Epoch 1/2, Batch 210, Loss: 2.1647, Accuracy: 0.2969, F1 Score: 0.1852
# Epoch 1/2, Batch 211, Loss: 2.2871, Accuracy: 0.1719, F1 Score: 0.0715
# Epoch 1/2, Batch 212, Loss: 2.2124, Accuracy: 0.2500, F1 Score: 0.1297
# Epoch 1/2, Batch 213, Loss: 2.1374, Accuracy: 0.3281, F1 Score: 0.1882
# Epoch 1/2, Batch 214, Loss: 2.0717, Accuracy: 0.3906, F1 Score: 0.2496
# Epoch 1/2, Batch 215, Loss: 2.1477, Accuracy: 0.3125, F1 Score: 0.1750
# Epoch 1/2, Batch 216, Loss: 2.1907, Accuracy: 0.2656, F1 Score: 0.1493
# Epoch 1/2, Batch 217, Loss: 2.1948, Accuracy: 0.2656, F1 Score: 0.1299
# Epoch 1/2, Batch 218, Loss: 2.1792, Accuracy: 0.2812, F1 Score: 0.1717
# Epoch 1/2, Batch 219, Loss: 2.2874, Accuracy: 0.1719, F1 Score: 0.0705
# Epoch 1/2, Batch 220, Loss: 2.2427, Accuracy: 0.2188, F1 Score: 0.1540
# Epoch 1/2, Batch 221, Loss: 2.2014, Accuracy: 0.2500, F1 Score: 0.1400
# Epoch 1/2, Batch 222, Loss: 2.1796, Accuracy: 0.2812, F1 Score: 0.1615
# Epoch 1/2, Batch 223, Loss: 2.1637, Accuracy: 0.2969, F1 Score: 0.1900
# Epoch 1/2, Batch 224, Loss: 2.2419, Accuracy: 0.2188, F1 Score: 0.1123
# Epoch 1/2, Batch 225, Loss: 2.1924, Accuracy: 0.2656, F1 Score: 0.1748
# Epoch 1/2, Batch 226, Loss: 2.1687, Accuracy: 0.2969, F1 Score: 0.1609
# Epoch 1/2, Batch 227, Loss: 2.2748, Accuracy: 0.1875, F1 Score: 0.1146
# Epoch 1/2, Batch 228, Loss: 2.1439, Accuracy: 0.3125, F1 Score: 0.2074
# Epoch 1/2, Batch 229, Loss: 2.2654, Accuracy: 0.2031, F1 Score: 0.1592
# Epoch 1/2, Batch 230, Loss: 2.2261, Accuracy: 0.2344, F1 Score: 0.1360
# Epoch 1/2, Batch 231, Loss: 2.1082, Accuracy: 0.3438, F1 Score: 0.2251
# Epoch 1/2, Batch 232, Loss: 2.2522, Accuracy: 0.2031, F1 Score: 0.1211
# Epoch 1/2, Batch 233, Loss: 2.1794, Accuracy: 0.2812, F1 Score: 0.1838
# Epoch 1/2, Batch 234, Loss: 2.2122, Accuracy: 0.2500, F1 Score: 0.1522
# Epoch 1/2, Batch 235, Loss: 2.1958, Accuracy: 0.2656, F1 Score: 0.1643
# Epoch 1/2, Batch 236, Loss: 2.1554, Accuracy: 0.2969, F1 Score: 0.1861
# Epoch 1/2, Batch 237, Loss: 2.3243, Accuracy: 0.1406, F1 Score: 0.0740
# Epoch 1/2, Batch 238, Loss: 2.0846, Accuracy: 0.3750, F1 Score: 0.2550
# Epoch 1/2, Batch 239, Loss: 2.1653, Accuracy: 0.2969, F1 Score: 0.1833
# Epoch 1/2, Batch 240, Loss: 2.2540, Accuracy: 0.2031, F1 Score: 0.1444
# Epoch 1/2, Batch 241, Loss: 2.2252, Accuracy: 0.2344, F1 Score: 0.1079
# Epoch 1/2, Batch 242, Loss: 2.2561, Accuracy: 0.2031, F1 Score: 0.1199
# Epoch 1/2, Batch 243, Loss: 2.1736, Accuracy: 0.2812, F1 Score: 0.1725
# Epoch 1/2, Batch 244, Loss: 2.1518, Accuracy: 0.3125, F1 Score: 0.1960
# Epoch 1/2, Batch 245, Loss: 2.1480, Accuracy: 0.3125, F1 Score: 0.1755
# Epoch 1/2, Batch 246, Loss: 2.0831, Accuracy: 0.3750, F1 Score: 0.2299
# Epoch 1/2, Batch 247, Loss: 2.2567, Accuracy: 0.2031, F1 Score: 0.0773
# Epoch 1/2, Batch 248, Loss: 2.1274, Accuracy: 0.3281, F1 Score: 0.1945
# Epoch 1/2, Batch 249, Loss: 2.2883, Accuracy: 0.1719, F1 Score: 0.0767
# Epoch 1/2, Batch 250, Loss: 2.1323, Accuracy: 0.3281, F1 Score: 0.1868
# Epoch 1/2, Batch 251, Loss: 2.1178, Accuracy: 0.3438, F1 Score: 0.2108
# Epoch 1/2, Batch 252, Loss: 2.1631, Accuracy: 0.2969, F1 Score: 0.1680
# Epoch 1/2, Batch 253, Loss: 2.2728, Accuracy: 0.1875, F1 Score: 0.1126
# Epoch 1/2, Batch 254, Loss: 2.1472, Accuracy: 0.3125, F1 Score: 0.1846
# Epoch 1/2, Batch 255, Loss: 2.1954, Accuracy: 0.2656, F1 Score: 0.1369
# Epoch 1/2, Batch 256, Loss: 2.3357, Accuracy: 0.1250, F1 Score: 0.0636
# Epoch 1/2, Batch 257, Loss: 2.3048, Accuracy: 0.1562, F1 Score: 0.1009
# Epoch 1/2, Batch 258, Loss: 2.1783, Accuracy: 0.2812, F1 Score: 0.1523
# Epoch 1/2, Batch 259, Loss: 2.2660, Accuracy: 0.1875, F1 Score: 0.0968
# Epoch 1/2, Batch 260, Loss: 2.1354, Accuracy: 0.3281, F1 Score: 0.1992
# Epoch 1/2, Batch 261, Loss: 2.2067, Accuracy: 0.2500, F1 Score: 0.1457
# Epoch 1/2, Batch 262, Loss: 2.3126, Accuracy: 0.1406, F1 Score: 0.0709
# Epoch 1/2, Batch 263, Loss: 2.1701, Accuracy: 0.2812, F1 Score: 0.1555
# Epoch 1/2, Batch 264, Loss: 2.2540, Accuracy: 0.2031, F1 Score: 0.1026
# Epoch 1/2, Batch 265, Loss: 2.2674, Accuracy: 0.1875, F1 Score: 0.0856
# Epoch 1/2, Batch 266, Loss: 2.1419, Accuracy: 0.3125, F1 Score: 0.1697
# Epoch 1/2, Batch 267, Loss: 2.1900, Accuracy: 0.2656, F1 Score: 0.1230
# Epoch 1/2, Batch 268, Loss: 2.2024, Accuracy: 0.2656, F1 Score: 0.1358
# Epoch 1/2, Batch 269, Loss: 1.9910, Accuracy: 0.4688, F1 Score: 0.3191
# Epoch 1/2, Batch 270, Loss: 2.1175, Accuracy: 0.3438, F1 Score: 0.1983
# Epoch 1/2, Batch 271, Loss: 2.1592, Accuracy: 0.2969, F1 Score: 0.1641
# Epoch 1/2, Batch 272, Loss: 2.1583, Accuracy: 0.2969, F1 Score: 0.1645
# Epoch 1/2, Batch 273, Loss: 2.1147, Accuracy: 0.3438, F1 Score: 0.2198
# Epoch 1/2, Batch 274, Loss: 2.1712, Accuracy: 0.2969, F1 Score: 0.1648
# Epoch 1/2, Batch 275, Loss: 2.1436, Accuracy: 0.3125, F1 Score: 0.1948
# Epoch 1/2, Batch 276, Loss: 2.1800, Accuracy: 0.2812, F1 Score: 0.1635
# Epoch 1/2, Batch 277, Loss: 2.2123, Accuracy: 0.2500, F1 Score: 0.1269
# Epoch 1/2, Batch 278, Loss: 2.1318, Accuracy: 0.3281, F1 Score: 0.2162
# Epoch 1/2, Batch 279, Loss: 2.2123, Accuracy: 0.2500, F1 Score: 0.1172
# Epoch 1/2, Batch 280, Loss: 2.1820, Accuracy: 0.2812, F1 Score: 0.1384
# Epoch 1/2, Batch 281, Loss: 2.0864, Accuracy: 0.3750, F1 Score: 0.2270
# Epoch 1/2, Batch 282, Loss: 2.1567, Accuracy: 0.3125, F1 Score: 0.1875
# Epoch 1/2, Batch 283, Loss: 2.2721, Accuracy: 0.1875, F1 Score: 0.0821
# Epoch 1/2, Batch 284, Loss: 2.1314, Accuracy: 0.3281, F1 Score: 0.2065
# Epoch 1/2, Batch 285, Loss: 2.1174, Accuracy: 0.3438, F1 Score: 0.2109
# Epoch 1/2, Batch 286, Loss: 2.0147, Accuracy: 0.4444, F1 Score: 0.3010
# Epoch 1/2, Train Loss: 2.2067, Train Accuracy: 0.2525, Train F1: 0.1391
# Epoch 1/2, Val Loss: 2.1867, Val Accuracy: 0.2764, Val F1: 0.1550
# Time for Epoch 1: 1326.21 seconds
# Epoch 2/2, Batch 0, Loss: 2.1414, Accuracy: 0.3125, F1 Score: 0.1599
# Epoch 2/2, Batch 1, Loss: 2.1735, Accuracy: 0.2969, F1 Score: 0.1686
# Epoch 2/2, Batch 2, Loss: 2.2567, Accuracy: 0.2031, F1 Score: 0.1185
# Epoch 2/2, Batch 3, Loss: 2.1164, Accuracy: 0.3438, F1 Score: 0.2401
# Epoch 2/2, Batch 4, Loss: 2.2250, Accuracy: 0.2344, F1 Score: 0.1358
# Epoch 2/2, Batch 5, Loss: 2.1720, Accuracy: 0.2969, F1 Score: 0.1879
# Epoch 2/2, Batch 6, Loss: 2.1196, Accuracy: 0.3438, F1 Score: 0.1978
# Epoch 2/2, Batch 7, Loss: 2.0916, Accuracy: 0.3750, F1 Score: 0.2438
# Epoch 2/2, Batch 8, Loss: 2.1240, Accuracy: 0.3281, F1 Score: 0.1931
# Epoch 2/2, Batch 9, Loss: 2.2112, Accuracy: 0.2500, F1 Score: 0.1259
# Epoch 2/2, Batch 10, Loss: 2.1810, Accuracy: 0.2812, F1 Score: 0.1543
# Epoch 2/2, Batch 11, Loss: 2.1945, Accuracy: 0.2656, F1 Score: 0.1349
# Epoch 2/2, Batch 12, Loss: 2.2102, Accuracy: 0.2500, F1 Score: 0.1294
# Epoch 2/2, Batch 13, Loss: 2.1482, Accuracy: 0.3125, F1 Score: 0.1707
# Epoch 2/2, Batch 14, Loss: 2.1615, Accuracy: 0.2969, F1 Score: 0.1725
# Epoch 2/2, Batch 15, Loss: 2.0981, Accuracy: 0.3594, F1 Score: 0.2373
# Epoch 2/2, Batch 16, Loss: 2.2133, Accuracy: 0.2500, F1 Score: 0.1274
# Epoch 2/2, Batch 17, Loss: 2.2608, Accuracy: 0.2031, F1 Score: 0.0932
# Epoch 2/2, Batch 18, Loss: 2.1800, Accuracy: 0.2812, F1 Score: 0.1491
# Epoch 2/2, Batch 19, Loss: 2.1708, Accuracy: 0.2969, F1 Score: 0.1717
# Epoch 2/2, Batch 20, Loss: 2.1774, Accuracy: 0.2812, F1 Score: 0.1444
# Epoch 2/2, Batch 21, Loss: 2.1493, Accuracy: 0.3125, F1 Score: 0.1598
# Epoch 2/2, Batch 22, Loss: 2.1794, Accuracy: 0.2812, F1 Score: 0.1351
# Epoch 2/2, Batch 23, Loss: 2.0965, Accuracy: 0.3594, F1 Score: 0.2079
# Epoch 2/2, Batch 24, Loss: 2.0715, Accuracy: 0.3906, F1 Score: 0.2339
# Epoch 2/2, Batch 25, Loss: 2.1969, Accuracy: 0.2656, F1 Score: 0.1665
# Epoch 2/2, Batch 26, Loss: 2.1382, Accuracy: 0.3281, F1 Score: 0.1789
# Epoch 2/2, Batch 27, Loss: 2.2265, Accuracy: 0.2344, F1 Score: 0.1258
# Epoch 2/2, Batch 28, Loss: 2.1269, Accuracy: 0.3281, F1 Score: 0.2154
# Epoch 2/2, Batch 29, Loss: 2.1789, Accuracy: 0.2812, F1 Score: 0.1538
# Epoch 2/2, Batch 30, Loss: 2.1456, Accuracy: 0.3125, F1 Score: 0.1778
# Epoch 2/2, Batch 31, Loss: 2.2584, Accuracy: 0.2031, F1 Score: 0.0837
# Epoch 2/2, Batch 32, Loss: 2.1317, Accuracy: 0.3281, F1 Score: 0.2212
# Epoch 2/2, Batch 33, Loss: 2.1014, Accuracy: 0.3594, F1 Score: 0.2041
# Epoch 2/2, Batch 34, Loss: 2.1210, Accuracy: 0.3438, F1 Score: 0.2092
# Epoch 2/2, Batch 35, Loss: 2.1643, Accuracy: 0.2969, F1 Score: 0.1516
# Epoch 2/2, Batch 36, Loss: 2.1639, Accuracy: 0.2969, F1 Score: 0.1546
# Epoch 2/2, Batch 37, Loss: 2.1035, Accuracy: 0.3594, F1 Score: 0.2078
# Epoch 2/2, Batch 38, Loss: 2.1945, Accuracy: 0.2656, F1 Score: 0.1499
# Epoch 2/2, Batch 39, Loss: 2.0493, Accuracy: 0.4062, F1 Score: 0.2778
# Epoch 2/2, Batch 40, Loss: 2.2160, Accuracy: 0.2500, F1 Score: 0.1555
# Epoch 2/2, Batch 41, Loss: 2.1634, Accuracy: 0.2969, F1 Score: 0.1572
# Epoch 2/2, Batch 42, Loss: 2.1307, Accuracy: 0.3281, F1 Score: 0.2085
# Epoch 2/2, Batch 43, Loss: 2.0857, Accuracy: 0.3750, F1 Score: 0.2351
# Epoch 2/2, Batch 44, Loss: 2.1326, Accuracy: 0.3281, F1 Score: 0.1758
# Epoch 2/2, Batch 45, Loss: 2.1942, Accuracy: 0.2656, F1 Score: 0.1270
# Epoch 2/2, Batch 46, Loss: 2.1272, Accuracy: 0.3281, F1 Score: 0.2032
# Epoch 2/2, Batch 47, Loss: 2.1263, Accuracy: 0.3281, F1 Score: 0.1964
# Epoch 2/2, Batch 48, Loss: 2.2574, Accuracy: 0.2031, F1 Score: 0.0754
# Epoch 2/2, Batch 49, Loss: 2.1961, Accuracy: 0.2656, F1 Score: 0.1328
# Epoch 2/2, Batch 50, Loss: 2.0964, Accuracy: 0.3594, F1 Score: 0.2113
# Epoch 2/2, Batch 51, Loss: 2.1354, Accuracy: 0.3281, F1 Score: 0.1769
# Epoch 2/2, Batch 52, Loss: 2.1792, Accuracy: 0.2812, F1 Score: 0.1689
# Epoch 2/2, Batch 53, Loss: 2.1477, Accuracy: 0.3125, F1 Score: 0.1686
# Epoch 2/2, Batch 54, Loss: 2.2260, Accuracy: 0.2344, F1 Score: 0.1104
# Epoch 2/2, Batch 55, Loss: 2.3341, Accuracy: 0.1250, F1 Score: 0.0368
# Epoch 2/2, Batch 56, Loss: 2.2225, Accuracy: 0.2344, F1 Score: 0.1254
# Epoch 2/2, Batch 57, Loss: 2.2421, Accuracy: 0.2188, F1 Score: 0.1040
# Epoch 2/2, Batch 58, Loss: 2.1787, Accuracy: 0.2812, F1 Score: 0.1619
# Epoch 2/2, Batch 59, Loss: 2.1951, Accuracy: 0.2656, F1 Score: 0.1250
# Epoch 2/2, Batch 60, Loss: 2.1623, Accuracy: 0.2969, F1 Score: 0.1710
# Epoch 2/2, Batch 61, Loss: 2.2086, Accuracy: 0.2500, F1 Score: 0.1401
# Epoch 2/2, Batch 62, Loss: 2.1665, Accuracy: 0.2969, F1 Score: 0.2062
# Epoch 2/2, Batch 63, Loss: 2.1945, Accuracy: 0.2656, F1 Score: 0.1328
# Epoch 2/2, Batch 64, Loss: 2.1637, Accuracy: 0.2969, F1 Score: 0.1811
# Epoch 2/2, Batch 65, Loss: 2.2523, Accuracy: 0.2031, F1 Score: 0.0936
# Epoch 2/2, Batch 66, Loss: 2.1658, Accuracy: 0.2969, F1 Score: 0.1544
# Epoch 2/2, Batch 67, Loss: 2.2100, Accuracy: 0.2500, F1 Score: 0.1531
# Epoch 2/2, Batch 68, Loss: 2.2056, Accuracy: 0.2656, F1 Score: 0.1350
# Epoch 2/2, Batch 69, Loss: 2.1639, Accuracy: 0.2969, F1 Score: 0.1917
# Epoch 2/2, Batch 70, Loss: 2.2585, Accuracy: 0.2031, F1 Score: 0.0996
# Epoch 2/2, Batch 71, Loss: 2.1405, Accuracy: 0.3125, F1 Score: 0.1700
# Epoch 2/2, Batch 72, Loss: 2.2066, Accuracy: 0.2500, F1 Score: 0.1278
# Epoch 2/2, Batch 73, Loss: 2.1458, Accuracy: 0.3125, F1 Score: 0.1858
# Epoch 2/2, Batch 74, Loss: 2.0861, Accuracy: 0.3750, F1 Score: 0.2334
# Epoch 2/2, Batch 75, Loss: 2.1168, Accuracy: 0.3281, F1 Score: 0.1931
# Epoch 2/2, Batch 76, Loss: 2.0704, Accuracy: 0.3906, F1 Score: 0.2513
# Epoch 2/2, Batch 77, Loss: 2.1993, Accuracy: 0.2656, F1 Score: 0.1507
# Epoch 2/2, Batch 78, Loss: 2.1474, Accuracy: 0.3125, F1 Score: 0.1793
# Epoch 2/2, Batch 79, Loss: 2.1638, Accuracy: 0.2969, F1 Score: 0.1810
# Epoch 2/2, Batch 80, Loss: 2.1832, Accuracy: 0.2812, F1 Score: 0.1674
# Epoch 2/2, Batch 81, Loss: 2.2095, Accuracy: 0.2500, F1 Score: 0.1223
# Epoch 2/2, Batch 82, Loss: 2.0587, Accuracy: 0.4062, F1 Score: 0.2914
# Epoch 2/2, Batch 83, Loss: 2.1506, Accuracy: 0.3125, F1 Score: 0.2037
# Epoch 2/2, Batch 84, Loss: 2.1352, Accuracy: 0.3281, F1 Score: 0.1918
# Epoch 2/2, Batch 85, Loss: 2.1911, Accuracy: 0.2656, F1 Score: 0.1454
# Epoch 2/2, Batch 86, Loss: 2.2114, Accuracy: 0.2500, F1 Score: 0.1343
# Epoch 2/2, Batch 87, Loss: 2.0855, Accuracy: 0.3750, F1 Score: 0.2247
# Epoch 2/2, Batch 88, Loss: 2.2258, Accuracy: 0.2344, F1 Score: 0.1152
# Epoch 2/2, Batch 89, Loss: 2.1871, Accuracy: 0.2812, F1 Score: 0.1674
# Epoch 2/2, Batch 90, Loss: 2.2061, Accuracy: 0.2500, F1 Score: 0.1250
# Epoch 2/2, Batch 91, Loss: 2.2409, Accuracy: 0.2188, F1 Score: 0.1011
# Epoch 2/2, Batch 92, Loss: 2.1441, Accuracy: 0.3125, F1 Score: 0.1751
# Epoch 2/2, Batch 93, Loss: 2.0631, Accuracy: 0.3906, F1 Score: 0.2545
# Epoch 2/2, Batch 94, Loss: 2.1482, Accuracy: 0.3125, F1 Score: 0.2049
# Epoch 2/2, Batch 95, Loss: 2.3046, Accuracy: 0.1562, F1 Score: 0.0821
# Epoch 2/2, Batch 96, Loss: 2.1477, Accuracy: 0.3125, F1 Score: 0.1849
# Epoch 2/2, Batch 97, Loss: 2.0085, Accuracy: 0.4531, F1 Score: 0.2896
# Epoch 2/2, Batch 98, Loss: 2.1636, Accuracy: 0.2969, F1 Score: 0.1757
# Epoch 2/2, Batch 99, Loss: 2.1575, Accuracy: 0.2969, F1 Score: 0.1544
# Epoch 2/2, Batch 100, Loss: 2.1476, Accuracy: 0.3125, F1 Score: 0.1818
# Epoch 2/2, Batch 101, Loss: 2.1486, Accuracy: 0.3125, F1 Score: 0.1639
# Epoch 2/2, Batch 102, Loss: 2.1407, Accuracy: 0.3125, F1 Score: 0.1885
# Epoch 2/2, Batch 103, Loss: 2.0544, Accuracy: 0.4062, F1 Score: 0.2481
# Epoch 2/2, Batch 104, Loss: 2.1233, Accuracy: 0.3438, F1 Score: 0.2051
# Epoch 2/2, Batch 105, Loss: 2.1472, Accuracy: 0.3125, F1 Score: 0.1624
# Epoch 2/2, Batch 106, Loss: 2.0705, Accuracy: 0.3906, F1 Score: 0.2529
# Epoch 2/2, Batch 107, Loss: 2.2882, Accuracy: 0.1719, F1 Score: 0.0874
# Epoch 2/2, Batch 108, Loss: 2.0862, Accuracy: 0.3750, F1 Score: 0.2235
# Epoch 2/2, Batch 109, Loss: 2.1341, Accuracy: 0.3281, F1 Score: 0.1867
# Epoch 2/2, Batch 110, Loss: 2.2780, Accuracy: 0.1875, F1 Score: 0.0885
# Epoch 2/2, Batch 111, Loss: 2.1482, Accuracy: 0.3125, F1 Score: 0.1902
# Epoch 2/2, Batch 112, Loss: 2.0864, Accuracy: 0.3750, F1 Score: 0.2625
# Epoch 2/2, Batch 113, Loss: 2.2077, Accuracy: 0.2500, F1 Score: 0.1473
# Epoch 2/2, Batch 114, Loss: 2.2421, Accuracy: 0.2188, F1 Score: 0.1042
# Epoch 2/2, Batch 115, Loss: 2.2253, Accuracy: 0.2344, F1 Score: 0.1158
# Epoch 2/2, Batch 116, Loss: 2.2386, Accuracy: 0.2188, F1 Score: 0.1071
# Epoch 2/2, Batch 117, Loss: 2.1950, Accuracy: 0.2656, F1 Score: 0.1477
# Epoch 2/2, Batch 118, Loss: 2.1793, Accuracy: 0.2812, F1 Score: 0.1333
# Epoch 2/2, Batch 119, Loss: 2.1948, Accuracy: 0.2656, F1 Score: 0.1434
# Epoch 2/2, Batch 120, Loss: 2.2359, Accuracy: 0.2188, F1 Score: 0.1017
# Epoch 2/2, Batch 121, Loss: 2.2792, Accuracy: 0.1719, F1 Score: 0.0778
# Epoch 2/2, Batch 122, Loss: 2.2263, Accuracy: 0.2344, F1 Score: 0.1241
# Epoch 2/2, Batch 123, Loss: 2.1566, Accuracy: 0.3125, F1 Score: 0.1809
# Epoch 2/2, Batch 124, Loss: 2.2105, Accuracy: 0.2500, F1 Score: 0.1132
# Epoch 2/2, Batch 125, Loss: 2.1792, Accuracy: 0.2812, F1 Score: 0.1566
# Epoch 2/2, Batch 126, Loss: 2.1869, Accuracy: 0.2656, F1 Score: 0.1372
# Epoch 2/2, Batch 127, Loss: 2.2123, Accuracy: 0.2500, F1 Score: 0.1313
# Epoch 2/2, Batch 128, Loss: 2.0972, Accuracy: 0.3594, F1 Score: 0.2397
# Epoch 2/2, Batch 129, Loss: 2.1949, Accuracy: 0.2656, F1 Score: 0.1412
# Epoch 2/2, Batch 130, Loss: 2.1993, Accuracy: 0.2656, F1 Score: 0.1414
# Epoch 2/2, Batch 131, Loss: 2.2080, Accuracy: 0.2500, F1 Score: 0.1309
# Epoch 2/2, Batch 132, Loss: 2.1359, Accuracy: 0.3281, F1 Score: 0.1891
# Epoch 2/2, Batch 133, Loss: 2.2053, Accuracy: 0.2500, F1 Score: 0.1620
# Epoch 2/2, Batch 134, Loss: 2.2388, Accuracy: 0.2188, F1 Score: 0.0965
# Epoch 2/2, Batch 135, Loss: 2.2108, Accuracy: 0.2500, F1 Score: 0.1071
# Epoch 2/2, Batch 136, Loss: 2.1636, Accuracy: 0.2969, F1 Score: 0.1812
# Epoch 2/2, Batch 137, Loss: 2.2409, Accuracy: 0.2188, F1 Score: 0.0925
# Epoch 2/2, Batch 138, Loss: 2.2677, Accuracy: 0.1875, F1 Score: 0.0887
# Epoch 2/2, Batch 139, Loss: 2.2120, Accuracy: 0.2500, F1 Score: 0.1307
# Epoch 2/2, Batch 140, Loss: 2.1272, Accuracy: 0.3281, F1 Score: 0.2069
# Epoch 2/2, Batch 141, Loss: 2.1918, Accuracy: 0.2656, F1 Score: 0.1575
# Epoch 2/2, Batch 142, Loss: 2.2374, Accuracy: 0.2188, F1 Score: 0.1166
# Epoch 2/2, Batch 143, Loss: 2.1483, Accuracy: 0.3125, F1 Score: 0.1646
# Epoch 2/2, Batch 144, Loss: 2.1640, Accuracy: 0.2969, F1 Score: 0.1624
# Epoch 2/2, Batch 145, Loss: 2.1958, Accuracy: 0.2656, F1 Score: 0.1440
# Epoch 2/2, Batch 146, Loss: 2.1292, Accuracy: 0.3281, F1 Score: 0.2102
# Epoch 2/2, Batch 147, Loss: 2.1632, Accuracy: 0.2969, F1 Score: 0.1700
# Epoch 2/2, Batch 148, Loss: 2.1370, Accuracy: 0.3281, F1 Score: 0.1779
# Epoch 2/2, Batch 149, Loss: 2.2085, Accuracy: 0.2500, F1 Score: 0.1294
# Epoch 2/2, Batch 150, Loss: 2.2100, Accuracy: 0.2500, F1 Score: 0.1481
# Epoch 2/2, Batch 151, Loss: 2.2199, Accuracy: 0.2344, F1 Score: 0.1193
# Epoch 2/2, Batch 152, Loss: 2.1095, Accuracy: 0.3438, F1 Score: 0.2128
# Epoch 2/2, Batch 153, Loss: 2.1184, Accuracy: 0.3438, F1 Score: 0.2104
# Epoch 2/2, Batch 154, Loss: 2.1954, Accuracy: 0.2656, F1 Score: 0.1442
# Epoch 2/2, Batch 155, Loss: 2.1631, Accuracy: 0.2969, F1 Score: 0.1729
# Epoch 2/2, Batch 156, Loss: 2.2148, Accuracy: 0.2500, F1 Score: 0.1476
# Epoch 2/2, Batch 157, Loss: 2.2086, Accuracy: 0.2500, F1 Score: 0.1139
# Epoch 2/2, Batch 158, Loss: 2.1736, Accuracy: 0.2812, F1 Score: 0.1674
# Epoch 2/2, Batch 159, Loss: 2.2508, Accuracy: 0.2031, F1 Score: 0.1036
# Epoch 2/2, Batch 160, Loss: 2.1789, Accuracy: 0.2812, F1 Score: 0.1582
# Epoch 2/2, Batch 161, Loss: 2.1376, Accuracy: 0.3125, F1 Score: 0.1949
# Epoch 2/2, Batch 162, Loss: 2.2113, Accuracy: 0.2500, F1 Score: 0.1548
# Epoch 2/2, Batch 163, Loss: 2.1311, Accuracy: 0.3281, F1 Score: 0.2107
# Epoch 2/2, Batch 164, Loss: 2.0855, Accuracy: 0.3750, F1 Score: 0.2558
# Epoch 2/2, Batch 165, Loss: 2.1415, Accuracy: 0.3125, F1 Score: 0.2231
# Epoch 2/2, Batch 166, Loss: 2.1584, Accuracy: 0.3125, F1 Score: 0.2257
# Epoch 2/2, Batch 167, Loss: 2.1977, Accuracy: 0.2656, F1 Score: 0.1796
# Epoch 2/2, Batch 168, Loss: 2.1099, Accuracy: 0.3438, F1 Score: 0.2349
# Epoch 2/2, Batch 169, Loss: 2.2320, Accuracy: 0.2188, F1 Score: 0.1375
# Epoch 2/2, Batch 170, Loss: 2.1758, Accuracy: 0.2812, F1 Score: 0.1640
# Epoch 2/2, Batch 171, Loss: 2.0971, Accuracy: 0.3750, F1 Score: 0.2650
# Epoch 2/2, Batch 172, Loss: 2.0534, Accuracy: 0.4062, F1 Score: 0.2976
# Epoch 2/2, Batch 173, Loss: 2.1877, Accuracy: 0.2656, F1 Score: 0.1919
# Epoch 2/2, Batch 174, Loss: 2.1255, Accuracy: 0.3281, F1 Score: 0.2225
# Epoch 2/2, Batch 175, Loss: 2.1012, Accuracy: 0.3594, F1 Score: 0.2600
# Epoch 2/2, Batch 176, Loss: 2.1145, Accuracy: 0.3438, F1 Score: 0.2303
# Epoch 2/2, Batch 177, Loss: 2.1428, Accuracy: 0.3125, F1 Score: 0.2268
# Epoch 2/2, Batch 178, Loss: 2.1695, Accuracy: 0.2812, F1 Score: 0.1966
# Epoch 2/2, Batch 179, Loss: 2.1943, Accuracy: 0.2656, F1 Score: 0.1453
# Epoch 2/2, Batch 180, Loss: 2.1319, Accuracy: 0.3281, F1 Score: 0.2408
# Epoch 2/2, Batch 181, Loss: 2.1683, Accuracy: 0.2969, F1 Score: 0.1995
# Epoch 2/2, Batch 182, Loss: 2.2070, Accuracy: 0.2500, F1 Score: 0.1579
# Epoch 2/2, Batch 183, Loss: 2.1149, Accuracy: 0.3281, F1 Score: 0.2266
# Epoch 2/2, Batch 184, Loss: 2.1750, Accuracy: 0.2812, F1 Score: 0.1922
# Epoch 2/2, Batch 185, Loss: 2.2583, Accuracy: 0.2031, F1 Score: 0.1269
# Epoch 2/2, Batch 186, Loss: 2.1621, Accuracy: 0.2969, F1 Score: 0.1961
# Epoch 2/2, Batch 187, Loss: 2.1487, Accuracy: 0.3125, F1 Score: 0.2240
# Epoch 2/2, Batch 188, Loss: 2.0570, Accuracy: 0.4062, F1 Score: 0.2946
# Epoch 2/2, Batch 189, Loss: 2.2405, Accuracy: 0.2188, F1 Score: 0.1339
# Epoch 2/2, Batch 190, Loss: 2.2020, Accuracy: 0.2500, F1 Score: 0.1491
# Epoch 2/2, Batch 191, Loss: 2.1389, Accuracy: 0.3125, F1 Score: 0.2060
# Epoch 2/2, Batch 192, Loss: 2.1047, Accuracy: 0.3594, F1 Score: 0.2554
# Epoch 2/2, Batch 193, Loss: 2.0379, Accuracy: 0.4219, F1 Score: 0.3260
# Epoch 2/2, Batch 194, Loss: 2.2284, Accuracy: 0.2344, F1 Score: 0.1520
# Epoch 2/2, Batch 195, Loss: 2.1499, Accuracy: 0.3125, F1 Score: 0.1806
# Epoch 2/2, Batch 196, Loss: 2.2185, Accuracy: 0.2344, F1 Score: 0.1421
# Epoch 2/2, Batch 197, Loss: 2.1879, Accuracy: 0.2812, F1 Score: 0.1695
# Epoch 2/2, Batch 198, Loss: 2.1762, Accuracy: 0.2812, F1 Score: 0.2135
# Epoch 2/2, Batch 199, Loss: 2.1725, Accuracy: 0.2812, F1 Score: 0.1849
# Epoch 2/2, Batch 200, Loss: 2.1299, Accuracy: 0.3281, F1 Score: 0.2122
# Epoch 2/2, Batch 201, Loss: 2.1105, Accuracy: 0.3438, F1 Score: 0.2685
# Epoch 2/2, Batch 202, Loss: 2.2543, Accuracy: 0.2031, F1 Score: 0.1268
# Epoch 2/2, Batch 203, Loss: 2.1604, Accuracy: 0.2969, F1 Score: 0.2217
# Epoch 2/2, Batch 204, Loss: 2.1788, Accuracy: 0.2812, F1 Score: 0.1829
# Epoch 2/2, Batch 205, Loss: 2.2583, Accuracy: 0.2031, F1 Score: 0.1076
# Epoch 2/2, Batch 206, Loss: 2.0991, Accuracy: 0.3594, F1 Score: 0.2488
# Epoch 2/2, Batch 207, Loss: 2.2626, Accuracy: 0.2031, F1 Score: 0.1019
# Epoch 2/2, Batch 208, Loss: 2.2296, Accuracy: 0.2188, F1 Score: 0.1501
# Epoch 2/2, Batch 209, Loss: 2.1322, Accuracy: 0.3281, F1 Score: 0.2385
# Epoch 2/2, Batch 210, Loss: 2.2066, Accuracy: 0.2500, F1 Score: 0.1607
# Epoch 2/2, Batch 211, Loss: 2.2577, Accuracy: 0.2031, F1 Score: 0.1059
# Epoch 2/2, Batch 212, Loss: 2.1395, Accuracy: 0.3125, F1 Score: 0.2304
# Epoch 2/2, Batch 213, Loss: 2.1366, Accuracy: 0.3281, F1 Score: 0.2208
# Epoch 2/2, Batch 214, Loss: 2.1488, Accuracy: 0.3125, F1 Score: 0.2220
# Epoch 2/2, Batch 215, Loss: 2.1488, Accuracy: 0.3125, F1 Score: 0.2169
# Epoch 2/2, Batch 216, Loss: 2.1267, Accuracy: 0.3281, F1 Score: 0.2135
# Epoch 2/2, Batch 217, Loss: 2.2290, Accuracy: 0.2344, F1 Score: 0.1255
# Epoch 2/2, Batch 218, Loss: 2.2096, Accuracy: 0.2500, F1 Score: 0.1813
# Epoch 2/2, Batch 219, Loss: 2.1649, Accuracy: 0.2969, F1 Score: 0.2109
# Epoch 2/2, Batch 220, Loss: 2.1693, Accuracy: 0.2969, F1 Score: 0.1876
# Epoch 2/2, Batch 221, Loss: 2.2037, Accuracy: 0.2500, F1 Score: 0.1875
# Epoch 2/2, Batch 222, Loss: 2.1791, Accuracy: 0.2812, F1 Score: 0.1568
# Epoch 2/2, Batch 223, Loss: 2.1506, Accuracy: 0.3125, F1 Score: 0.2107
# Epoch 2/2, Batch 224, Loss: 2.2354, Accuracy: 0.2188, F1 Score: 0.1136
# Epoch 2/2, Batch 225, Loss: 2.1590, Accuracy: 0.2969, F1 Score: 0.1974
# Epoch 2/2, Batch 226, Loss: 2.2426, Accuracy: 0.2188, F1 Score: 0.1699
# Epoch 2/2, Batch 227, Loss: 1.9674, Accuracy: 0.5000, F1 Score: 0.3901
# Epoch 2/2, Batch 228, Loss: 2.1319, Accuracy: 0.3281, F1 Score: 0.2384
# Epoch 2/2, Batch 229, Loss: 2.1274, Accuracy: 0.3281, F1 Score: 0.2190
# Epoch 2/2, Batch 230, Loss: 2.2339, Accuracy: 0.2344, F1 Score: 0.1414
# Epoch 2/2, Batch 231, Loss: 2.2251, Accuracy: 0.2344, F1 Score: 0.1585
# Epoch 2/2, Batch 232, Loss: 2.1632, Accuracy: 0.2969, F1 Score: 0.2314
# Epoch 2/2, Batch 233, Loss: 2.1173, Accuracy: 0.3438, F1 Score: 0.2448
# Epoch 2/2, Batch 234, Loss: 2.1515, Accuracy: 0.3125, F1 Score: 0.1919
# Epoch 2/2, Batch 235, Loss: 2.1173, Accuracy: 0.3438, F1 Score: 0.2269
# Epoch 2/2, Batch 236, Loss: 2.1058, Accuracy: 0.3438, F1 Score: 0.2413
# Epoch 2/2, Batch 237, Loss: 2.1299, Accuracy: 0.3281, F1 Score: 0.2371
# Epoch 2/2, Batch 238, Loss: 2.1063, Accuracy: 0.3594, F1 Score: 0.2473
# Epoch 2/2, Batch 239, Loss: 2.1644, Accuracy: 0.2969, F1 Score: 0.2025
# Epoch 2/2, Batch 240, Loss: 2.2087, Accuracy: 0.2500, F1 Score: 0.1628
# Epoch 2/2, Batch 241, Loss: 2.1845, Accuracy: 0.2656, F1 Score: 0.1809
# Epoch 2/2, Batch 242, Loss: 2.1641, Accuracy: 0.2969, F1 Score: 0.2031
# Epoch 2/2, Batch 243, Loss: 2.0520, Accuracy: 0.4062, F1 Score: 0.3029
# Epoch 2/2, Batch 244, Loss: 2.1468, Accuracy: 0.3125, F1 Score: 0.2264
# Epoch 2/2, Batch 245, Loss: 2.1185, Accuracy: 0.3438, F1 Score: 0.2220
# Epoch 2/2, Batch 246, Loss: 2.2677, Accuracy: 0.1875, F1 Score: 0.1084
# Epoch 2/2, Batch 247, Loss: 2.1282, Accuracy: 0.3281, F1 Score: 0.2306
# Epoch 2/2, Batch 248, Loss: 2.2517, Accuracy: 0.2031, F1 Score: 0.1088
# Epoch 2/2, Batch 249, Loss: 2.2129, Accuracy: 0.2500, F1 Score: 0.1446
# Epoch 2/2, Batch 250, Loss: 2.2876, Accuracy: 0.1719, F1 Score: 0.0804
# Epoch 2/2, Batch 251, Loss: 2.2382, Accuracy: 0.2188, F1 Score: 0.1015
# Epoch 2/2, Batch 252, Loss: 2.2836, Accuracy: 0.1719, F1 Score: 0.0995
# Epoch 2/2, Batch 253, Loss: 2.1015, Accuracy: 0.3594, F1 Score: 0.2491
# Epoch 2/2, Batch 254, Loss: 2.2262, Accuracy: 0.2344, F1 Score: 0.2052
# Epoch 2/2, Batch 255, Loss: 2.2155, Accuracy: 0.2500, F1 Score: 0.1438
# Epoch 2/2, Batch 256, Loss: 2.2792, Accuracy: 0.1719, F1 Score: 0.1274
# Epoch 2/2, Batch 257, Loss: 2.2886, Accuracy: 0.1719, F1 Score: 0.0894
# Epoch 2/2, Batch 258, Loss: 2.1691, Accuracy: 0.2969, F1 Score: 0.1770
# Epoch 2/2, Batch 259, Loss: 2.1172, Accuracy: 0.3438, F1 Score: 0.2169
# Epoch 2/2, Batch 260, Loss: 2.1790, Accuracy: 0.2812, F1 Score: 0.1659
# Epoch 2/2, Batch 261, Loss: 2.3020, Accuracy: 0.1562, F1 Score: 0.1092
# Epoch 2/2, Batch 262, Loss: 2.2900, Accuracy: 0.1719, F1 Score: 0.1250
# Epoch 2/2, Batch 263, Loss: 2.2111, Accuracy: 0.2500, F1 Score: 0.1373
# Epoch 2/2, Batch 264, Loss: 2.1708, Accuracy: 0.2969, F1 Score: 0.1751
# Epoch 2/2, Batch 265, Loss: 2.1340, Accuracy: 0.3281, F1 Score: 0.2304
# Epoch 2/2, Batch 266, Loss: 2.1182, Accuracy: 0.3438, F1 Score: 0.2313
# Epoch 2/2, Batch 267, Loss: 2.1007, Accuracy: 0.3594, F1 Score: 0.2483
# Epoch 2/2, Batch 268, Loss: 2.1441, Accuracy: 0.3125, F1 Score: 0.2159
# Epoch 2/2, Batch 269, Loss: 2.2436, Accuracy: 0.2188, F1 Score: 0.1305
# Epoch 2/2, Batch 270, Loss: 2.1720, Accuracy: 0.2812, F1 Score: 0.1823
# Epoch 2/2, Batch 271, Loss: 2.2384, Accuracy: 0.2188, F1 Score: 0.1309
# Epoch 2/2, Batch 272, Loss: 2.2574, Accuracy: 0.2031, F1 Score: 0.0984
# Epoch 2/2, Batch 273, Loss: 2.1020, Accuracy: 0.3594, F1 Score: 0.2186
# Epoch 2/2, Batch 274, Loss: 2.2415, Accuracy: 0.2188, F1 Score: 0.1018
# Epoch 2/2, Batch 275, Loss: 2.0714, Accuracy: 0.3906, F1 Score: 0.2601
# Epoch 2/2, Batch 276, Loss: 2.0561, Accuracy: 0.4062, F1 Score: 0.2734
# Epoch 2/2, Batch 277, Loss: 2.1499, Accuracy: 0.3125, F1 Score: 0.2181
# Epoch 2/2, Batch 278, Loss: 2.1091, Accuracy: 0.3438, F1 Score: 0.2076
# Epoch 2/2, Batch 279, Loss: 2.1801, Accuracy: 0.2812, F1 Score: 0.1632
# Epoch 2/2, Batch 280, Loss: 2.1530, Accuracy: 0.3125, F1 Score: 0.1863
# Epoch 2/2, Batch 281, Loss: 2.0015, Accuracy: 0.4531, F1 Score: 0.3262
# Epoch 2/2, Batch 282, Loss: 2.1124, Accuracy: 0.3438, F1 Score: 0.2074
# Epoch 2/2, Batch 283, Loss: 2.2396, Accuracy: 0.2188, F1 Score: 0.1201
# Epoch 2/2, Batch 284, Loss: 2.2094, Accuracy: 0.2500, F1 Score: 0.1481
# Epoch 2/2, Batch 285, Loss: 2.1725, Accuracy: 0.2812, F1 Score: 0.1597
# Epoch 2/2, Batch 286, Loss: 2.2409, Accuracy: 0.2222, F1 Score: 0.1561
# Epoch 2/2, Train Loss: 2.1709, Train Accuracy: 0.2889, Train F1: 0.1753
# Epoch 2/2, Val Loss: 2.1535, Val Accuracy: 0.3092, Val F1: 0.1867
# Time for Epoch 2: 1178.77 seconds

# %%
torch.save(model.state_dict(), r'C:\Users\іванна\PycharmProjects\python-for-big-data-and-data-science\nn1\simple_cnn_model.pth')

# %%
torch.save(model, 'full_model.pth')

# %%
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(12, 6))
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(epochs, train_f1_scores, label='Train F1 Score')
plt.plot(epochs, val_f1_scores, label='Validation F1 Score')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('Training and Validation F1 Score')
plt.legend()
plt.show()
